# %%
! pip install ultralytics --quiet

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
dataset_path = '/kaggle/input/yolo-dataset/yolo_dataset/data'

# %%
yaml_file = '/kaggle/input/yolo-dataset/config3.yaml'

# %%
import torch

# %%
if torch.cuda.is_available():
    print("GPU is available.")
else:
    print("GPU is not available. Training might be slow.")
# Out:
# GPU is available.

# %%
print(f"Number of available GPUs: {torch.cuda.device_count()}")
for i in range(torch.cuda.device_count()):
    print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
# Out:
# Number of available GPUs: 1
# GPU 0: Tesla P100-PCIE-16GB

# %%
model = YOLO('yolo11l.pt')
# Out:
# ...
# 100%|██████████| 49.0M/49.0M [00:02<00:00, 23.7MB/s]

# %%
model.info()
# Out:
# YOLO11l summary: 631 layers, 25,317,419 parameters, 25,317,403 gradients, 87.3 GFLOPs
# (631, 25317419, 25317403, 87.3081344)

# %%
model.train(
    data=yaml_file,
    epochs=100,  # Adjust as needed
    imgsz=640,
    batch=16,  # Adjust based on your GPU memory
    workers=8,  # Adjust based on your CPU
    augment=True
)
# Out:
# Ultralytics 8.3.1 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
# Evaluate on the test set
model.val()
# Out:
# Ultralytics 8.3.1 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLO11l summary (fused): 464 layers, 25,286,251 parameters, 0 gradients, 86.6 GFLOPs
# val: Scanning /kaggle/input/yolo-dataset/yolo_dataset/data/labels/valid... 217 images, 0 backgrounds, 0 corrupt: 100%|██████████| 217/217 [00:00<00:00, 861.67it/s]
# val: WARNING ⚠️ Cache directory /kaggle/input/yolo-dataset/yolo_dataset/data/labels is not writeable, cache not saved.
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 14/14 [00:10<00:00,  1.38it/s]
#                    all        217        375      0.732      0.736      0.778      0.618
# ...

# %%
import shutil

# %%
# !zip -r file.zip /kaggle/working --quiet
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()

# %%
# !ls
# Out:
# file.zip  runs	wandb  yolo11l.pt  yolo11n.pt

# %%
from IPython.display import FileLinks
FileLinks(r'runs/')
# Out:
# runs/detect/train/
#   events.out.tfevents.1727754469.080dbfbc6bb7.30.0
#   args.yaml
# runs/detect/train2/
#   labels.jpg
#   val_batch2_labels.jpg
#   results.csv
#   train_batch2.jpg
#   train_batch4140.jpg
#   labels_correlogram.jpg
#   val_batch0_pred.jpg
#   events.out.tfevents.1727754750.080dbfbc6bb7.30.1
#   train_batch4142.jpg
#   val_batch1_pred.jpg
#   confusion_matrix.png
#   val_batch1_labels.jpg
#   results.png
#   val_batch0_labels.jpg
#   P_curve.png
#   F1_curve.png
#   train_batch0.jpg
#   args.yaml
#   confusion_matrix_normalized.png
#   PR_curve.png
#   val_batch2_pred.jpg
#   train_batch1.jpg
#   R_curve.png
#   train_batch4141.jpg
# runs/detect/train2/weights/
#   best.pt
#   last.pt
# runs/detect/train22/
#   val_batch2_labels.jpg
#   val_batch0_pred.jpg
#   val_batch1_pred.jpg
#   confusion_matrix.png
#   val_batch1_labels.jpg
#   val_batch0_labels.jpg
#   P_curve.png
#   F1_curve.png
#   confusion_matrix_normalized.png
#   PR_curve.png
# ...
